# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Q1

# %% [markdown]
# matplot is a popular library for pyhton, it is use for it provide wide range for tools creating plot,charts, histograms, scatterplots, and other types of visualizations to help researchers, data analysts, and developers in data exploration and presentation.
# five plot can be plotted using pyplot
# line plot, pie chart, bar plot, histogram, scatter plot

# %%
#Q2
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
plt.scatter(x, y)
plt.xlabel("X- Axis")
plt.ylabel("y-Axis")
plt.title('x, y orientaion')
# Out:
# Text(0.5, 1.0, 'x, y orientaion')

# %%
#Q4 a chart that represent categorical data in the form of rectangular shape
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company, profit)
# Out:
# <BarContainer object of 4 artists>

# %%
#A box plot, also known as a box-and-whisker plot, is a type of graphical representation that displays the distribution of a dataset along with key statistical measures#
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
data_to_plot = [box1, box2]
labels = ['Box1']
